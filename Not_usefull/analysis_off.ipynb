# %% [markdown]
# ### Use for cold start  problem

# %%
import pandas as pd
import numpy as np
import math
import random

# %%
import json
with open("anime-offline-database.json", encoding='utf-8') as f:
    data = json.load(f)

print(type(data))  # Check if it's a list or dict
# Out:
# <class 'dict'>

# %%
data['data']
# Out:
# [{'sources': ['https://anilist.co/anime/142051',
#    'https://anime-planet.com/anime/raise-a-suilen-nvade-show',
#    'https://kitsu.app/anime/47450',
#    'https://myanimelist.net/anime/51478'],
#   'title': '!NVADE SHOW!',
#   'type': 'SPECIAL',
#   'episodes': 1,
#   'status': 'FINISHED',
#   'animeSeason': {'season': 'FALL', 'year': 2020},
#   'picture': 'https://cdn.myanimelist.net/images/anime/1930/122178.jpg',
#   'thumbnail': 'https://cdn.myanimelist.net/images/anime/1930/122178t.jpg',
#   'duration': {'value': 120, 'unit': 'SECONDS'},
#   'score': {'arithmeticGeometricMean': 6.282475516101638,
#    'arithmeticMean': 6.286787878787879,
#    'median': 6.374},
#   'synonyms': ['!nvade Show!',
#    'Invade Show!',
#    'RAISE A SUILEN',
#    'RAISE A SUILEN: !NVADE SHOW!'],
#   'relatedAnime': ['https://anilist.co/anime/101633',
#    'https://kitsu.app/anime/12330',
#    'https://myanimelist.net/anime/37869'],
#   'tags': ['band',
#    'full cgi',
#    'music',
# ...
