# %%
import pandas as pd
anime_data = pd.read_csv('anime_clean.csv')

# %%
anime_data.head()
# Out:
#    anime_id                                name  \
# 0     52991                   Sousou no Frieren
# 1      5114    Fullmetal Alchemist: Brotherhood
# 2      9253                         Steins;Gate
# 3     38524  Shingeki no Kyojin Season 3 Part 2
# 4     28977                            Gintama°
#
#                       title_english type  episodes  rating  popularity  \
# 0     Frieren: Beyond Journey's End   TV      28.0    9.30         142
# 1  Fullmetal Alchemist: Brotherhood   TV      64.0    9.10           3
# 2                       Steins;Gate   TV      24.0    9.07          14
# 3   Attack on Titan Season 3 Part 2   TV      10.0    9.05          21
# 4                  Gintama Season 4   TV      51.0    9.05         343
#
#    members           status        source       duration  \
# 0  1119371  Finished Airing         Manga  24 min per ep
# 1  3522284  Finished Airing         Manga  24 min per ep
# 2  2697581  Finished Airing  Visual novel  24 min per ep
# ...

# %%
# Combine anime name and id into one column

# Drop specified columns
anime_data = anime_data.drop(['name', 'title_english', 'duration', 'aired_to_year'], axis=1)

# %%
anime_data.head()
# Out:
#    anime_id type  episodes  rating  popularity  members           status  \
# 0     52991   TV      28.0    9.30         142  1119371  Finished Airing
# 1      5114   TV      64.0    9.10           3  3522284  Finished Airing
# 2      9253   TV      24.0    9.07          14  2697581  Finished Airing
# 3     38524   TV      10.0    9.05          21  2445236  Finished Airing
# 4     28977   TV      51.0    9.05         343   667240  Finished Airing
#
#          source                              genre                 studio  \
# 0         Manga          Adventure, Drama, Fantasy               Madhouse
# 1         Manga  Action, Adventure, Drama, Fantasy                  Bones
# 2  Visual novel            Drama, Sci-Fi, Suspense              White Fox
# 3         Manga            Action, Drama, Suspense             Wit Studio
# 4         Manga             Action, Comedy, Sci-Fi  Bandai Namco Pictures
#
#                                             synopsis  aired_from_year  \
# ...

# %%
anime_data.to_csv('anime_surprise.csv', index=False)

# %%
anime_data.head()
# Out:
#    anime_id type  episodes  rating  popularity  members           status  \
# 0     52991   TV      28.0    9.30         142  1119371  Finished Airing
# 1      5114   TV      64.0    9.10           3  3522284  Finished Airing
# 2      9253   TV      24.0    9.07          14  2697581  Finished Airing
# 3     38524   TV      10.0    9.05          21  2445236  Finished Airing
# 4     28977   TV      51.0    9.05         343   667240  Finished Airing
#
#          source                              genre                 studio  \
# 0         Manga          Adventure, Drama, Fantasy               Madhouse
# 1         Manga  Action, Adventure, Drama, Fantasy                  Bones
# 2  Visual novel            Drama, Sci-Fi, Suspense              White Fox
# 3         Manga            Action, Drama, Suspense             Wit Studio
# 4         Manga             Action, Comedy, Sci-Fi  Bandai Namco Pictures
#
#                                             synopsis  aired_from_year  \
# ...
